# %%
import pandas as pd

# %%
glacier_length = pd.read_csv("data\lengthchange.csv", sep = ";", header= 4)
glacier_length.head()
# Out:
#          glacier name                              glacier id  \
# 0                 NaN  (according to Swiss Glacier Inventory)
# 1                 NaN                                     NaN
# 2  Silvrettagletscher                                 A10g-05
# 3  Silvrettagletscher                                 A10g-05
# 4  Silvrettagletscher                                 A10g-05
#
#   start date of observation       quality of start date  \
# 0                date_start  x = date not exactly known
# 1     yyyy-mm-dd (ISO 8601)                         NaN
# 2                1956-09-01                           x
# 3                1957-09-01                           x
# 4                1958-09-01                           x
#
#   end date of observation         quality of end date length change  \
# 0                date_end  x = date not exactly known            dL
# 1   yyyy-mm-dd (ISO 8601)                         NaN             m
# ...

# %%
glacier_massbalance = pd.read_csv("data\massbalance_observation.csv", sep = ";", header= 4)
glacier_massbalance.head()
# Out:
#          glacier name                              glacier id  \
# 0                 NaN  (according to Swiss Glacier Inventory)
# 1                 NaN                                     NaN
# 2  Silvrettagletscher                                 A10g-05
# 3  Silvrettagletscher                                 A10g-05
# 4  Silvrettagletscher                                 A10g-05
#
#   start date of observation end date of winter observation  \
# 0                date_start                date_end_winter
# 1     yyyy-mm-dd (ISO 8601)          yyyy-mm-dd (ISO 8601)
# 2                1914-10-01                     1915-04-30
# 3                1915-09-29                     1916-05-15
# 4                1916-08-05                     1917-03-11
#
#   end date of observation winter mass balance summer mass balance  \
# 0                date_end                  Bw                  Bs
# 1   yyyy-mm-dd (ISO 8601)             mm w.e.             mm w.e.
# ...

# %%
glacier_volumechange = pd.read_csv("data\Volumechange.csv", sep = ";", header = 4)
glacier_volumechange.head()
# Out:
#          glacier name                              glacier id  \
# 0                 NaN  (according to Swiss Glacier Inventory)
# 1                 NaN                                     NaN
# 2  Silvrettagletscher                                 A10g-05
# 3  Silvrettagletscher                                 A10g-05
# 4  Silvrettagletscher                                 A10g-05
#
#   start date of observation       quality of start date  \
# 0                date_start  x = date not exactly known
# 1     yyyy-mm-dd (ISO 8601)                         NaN
# 2                1938-09-01                           x
# 3                1959-08-31                         NaN
# 4                1973-09-12                         NaN
#
#   end date of observation     quality of start date.1  \
# 0                date_end  x = date not exactly known
# 1   yyyy-mm-dd (ISO 8601)                         NaN
# 2              1959-08-31                         NaN
# ...
